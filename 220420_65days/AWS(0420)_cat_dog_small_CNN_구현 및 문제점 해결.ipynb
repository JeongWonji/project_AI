# %%
# 일부 이미지 분리(총 4000개)

import os, shutil

original_dataset_dir = './data/cat_dog/train'

## directory 생성 ##

base_dir = 'data/cat_dog_small'
os.mkdir(base_dir)

train_dir = os.path.join(base_dir,'train')
os.mkdir(train_dir)
validation_dir = os.path.join(base_dir,'validation')
os.mkdir(validation_dir)
test_dir = os.path.join(base_dir,'test')
os.mkdir(test_dir)

train_cats_dir = os.path.join(train_dir,'cats')
os.mkdir(train_cats_dir)
train_dogs_dir = os.path.join(train_dir,'dogs')
os.mkdir(train_dogs_dir)

validation_cats_dir = os.path.join(validation_dir,'cats')
os.mkdir(validation_cats_dir)
validation_dogs_dir = os.path.join(validation_dir,'dogs')
os.mkdir(validation_dogs_dir)

test_cats_dir = os.path.join(test_dir,'cats')
os.mkdir(test_cats_dir)
test_dogs_dir = os.path.join(test_dir,'dogs')
os.mkdir(test_dogs_dir)

## file 복사 ##

fnames = ['cat.{}.jpg'.format(i) for i in range(1000)]
for fname in fnames:
    src = os.path.join(original_dataset_dir,fname)
    dst = os.path.join(train_cats_dir, fname)
    shutil.copyfile(src,dst)

fnames = ['cat.{}.jpg'.format(i) for i in range(1000,1500)]
for fname in fnames:
    src = os.path.join(original_dataset_dir,fname)
    dst = os.path.join(validation_cats_dir, fname)
    shutil.copyfile(src,dst)
    
fnames = ['cat.{}.jpg'.format(i) for i in range(1500,2000)]
for fname in fnames:
    src = os.path.join(original_dataset_dir,fname)
    dst = os.path.join(test_cats_dir, fname)
    shutil.copyfile(src,dst)
    

fnames = ['dog.{}.jpg'.format(i) for i in range(1000)]
for fname in fnames:
    src = os.path.join(original_dataset_dir,fname)
    dst = os.path.join(train_dogs_dir, fname)
    shutil.copyfile(src,dst)

fnames = ['dog.{}.jpg'.format(i) for i in range(1000,1500)]
for fname in fnames:
    src = os.path.join(original_dataset_dir,fname)
    dst = os.path.join(validation_dogs_dir, fname)
    shutil.copyfile(src,dst)
    
fnames = ['dog.{}.jpg'.format(i) for i in range(1500,2000)]
for fname in fnames:
    src = os.path.join(original_dataset_dir,fname)
    dst = os.path.join(test_dogs_dir, fname)
    shutil.copyfile(src,dst)

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

train_dir = './data/cat_dog_small/train'    # cats folder, dogs folder
valid_dir = './data/cat_dog_small/validation'

# ImageDataGenerator를 생성해요!
train_datagen = ImageDataGenerator(rescale=1/255)
validation_datagen = ImageDataGenerator(rescale=1/255)

train_generator = train_datagen.flow_from_directory(
    train_dir,    # target directory
    classes=['cats', 'dogs'],
    target_size=(150,150),
    batch_size=20,
    class_mode='binary'
)

validation_generator = validation_datagen.flow_from_directory(
    valid_dir,    # target directory
    classes=['cats', 'dogs'],
    target_size=(150,150),
    batch_size=20,
    class_mode='binary'
)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop

model = Sequential()

model.add(Conv2D(filters=32,
                 kernel_size=(3,3),
                 activation='relu',
                 input_shape=(150,150,3)))

model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64,
                 kernel_size=(3,3),
                 activation='relu'))

model.add(Conv2D(filters=128,
                 kernel_size=(3,3),
                 activation='relu'))

model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=128,
                 kernel_size=(3,3),
                 activation='relu'))

model.add(MaxPooling2D(pool_size=(2,2)))

#### feature extraction ####

model.add(Flatten())

model.add(Dense(units=256,
                activation='relu'))

model.add(Dense(units=1,
                activation='sigmoid'))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 70, 70, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 35, 35, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 33, 33, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               8388864
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 8,629,953
# Trainable params: 8,629,953
# Non-trainable params: 0
# _________________________________________________________________
# None
# 2022-04-20 10:04:12.490283: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-04-20 10:04:12.491292: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-20 10:04:12.492260: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_generator,    # 2000개 이미지 , 20개씩 뽑아내.. 100번
                   steps_per_epoch=100,
                   epochs=30,
                   validation_data=validation_generator,  # 1000개 이미지 , 20개
                   validation_steps=50)

model.save('./data/cats_dogs_small_cnn_model.h5')
# Out:
# 2022-04-20 10:06:29.074954: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-04-20 10:06:29.097467: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2499995000 Hz
# Epoch 1/30
# 100/100 [==============================] - 68s 670ms/step - loss: 0.7029 - accuracy: 0.4936 - val_loss: 0.6877 - val_accuracy: 0.5530
# Epoch 2/30
# 100/100 [==============================] - 66s 662ms/step - loss: 0.6790 - accuracy: 0.5964 - val_loss: 0.6580 - val_accuracy: 0.6110
# Epoch 3/30
# 100/100 [==============================] - 67s 669ms/step - loss: 0.6338 - accuracy: 0.6469 - val_loss: 0.6126 - val_accuracy: 0.6680
# Epoch 4/30
# 100/100 [==============================] - 68s 681ms/step - loss: 0.5789 - accuracy: 0.7065 - val_loss: 0.6141 - val_accuracy: 0.6610
# Epoch 5/30
# 100/100 [==============================] - 67s 670ms/step - loss: 0.5109 - accuracy: 0.7340 - val_loss: 0.5776 - val_accuracy: 0.6820
# Epoch 6/30
# 100/100 [==============================] - 68s 679ms/step - loss: 0.4469 - accuracy: 0.7885 - val_loss: 0.5679 - val_accuracy: 0.7080
# Epoch 7/30
# 100/100 [==============================] - 68s 677ms/step - loss: 0.4263 - accuracy: 0.7951 - val_loss: 0.5799 - val_accuracy: 0.7030
# Epoch 8/30
# 100/100 [==============================] - 67s 671ms/step - loss: 0.3910 - accuracy: 0.8354 - val_loss: 0.6215 - val_accuracy: 0.7030
# Epoch 9/30
# 100/100 [==============================] - 68s 675ms/step - loss: 0.3709 - accuracy: 0.8411 - val_loss: 0.5802 - val_accuracy: 0.7310
# Epoch 10/30
# 100/100 [==============================] - 68s 676ms/step - loss: 0.3085 - accuracy: 0.8681 - val_loss: 0.6079 - val_accuracy: 0.7060
# Epoch 11/30
# 100/100 [==============================] - 67s 668ms/step - loss: 0.2743 - accuracy: 0.8855 - val_loss: 0.6543 - val_accuracy: 0.7040
# Epoch 12/30
# 100/100 [==============================] - 67s 667ms/step - loss: 0.2611 - accuracy: 0.9012 - val_loss: 0.6609 - val_accuracy: 0.7110
# Epoch 13/30
# 100/100 [==============================] - 67s 669ms/step - loss: 0.2139 - accuracy: 0.9260 - val_loss: 0.6681 - val_accuracy: 0.7310
# Epoch 14/30
# 100/100 [==============================] - 67s 674ms/step - loss: 0.1867 - accuracy: 0.9308 - val_loss: 0.7031 - val_accuracy: 0.7270
# Epoch 15/30
# 100/100 [==============================] - 68s 679ms/step - loss: 0.1491 - accuracy: 0.9503 - val_loss: 0.7912 - val_accuracy: 0.7040
# Epoch 16/30
# 100/100 [==============================] - 69s 688ms/step - loss: 0.1339 - accuracy: 0.9639 - val_loss: 0.8805 - val_accuracy: 0.7280
# Epoch 17/30
# 100/100 [==============================] - 68s 682ms/step - loss: 0.0785 - accuracy: 0.9823 - val_loss: 0.9161 - val_accuracy: 0.7310
# Epoch 18/30
# 100/100 [==============================] - 67s 675ms/step - loss: 0.0755 - accuracy: 0.9850 - val_loss: 1.0383 - val_accuracy: 0.7000
# Epoch 19/30
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0609 - accuracy: 0.9853 - val_loss: 1.0272 - val_accuracy: 0.7160
# Epoch 20/30
# 100/100 [==============================] - 68s 681ms/step - loss: 0.0329 - accuracy: 0.9971 - val_loss: 1.0779 - val_accuracy: 0.7230
# Epoch 21/30
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0203 - accuracy: 0.9988 - val_loss: 1.1987 - val_accuracy: 0.7190
# Epoch 22/30
# 100/100 [==============================] - 68s 682ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 1.2749 - val_accuracy: 0.7160
# Epoch 23/30
# 100/100 [==============================] - 69s 687ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.3633 - val_accuracy: 0.7160
# Epoch 24/30
# 100/100 [==============================] - 68s 675ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.4146 - val_accuracy: 0.7150
# Epoch 25/30
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.4512 - val_accuracy: 0.7200
# Epoch 26/30
# 100/100 [==============================] - 68s 678ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.5072 - val_accuracy: 0.7240
# Epoch 27/30
# 100/100 [==============================] - 68s 685ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.5573 - val_accuracy: 0.7230
# Epoch 28/30
# 100/100 [==============================] - 68s 678ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.5970 - val_accuracy: 0.7210
# Epoch 29/30
# 100/100 [==============================] - 67s 674ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.6468 - val_accuracy: 0.7230
# Epoch 30/30
# 100/100 [==============================] - 68s 676ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.6581 - val_accuracy: 0.7210

# %%
import matplotlib.pyplot as plt

train_acc = history.history['accuracy']
valid_acc = history.history['val_accuracy']

train_loss = history.history['loss']
valid_loss = history.history['val_loss']

figure = plt.figure()
ax1 = figure.add_subplot(1,2,1)
ax2 = figure.add_subplot(1,2,2)

ax1.plot(train_acc, color='r', label='train accuracy')
ax1.plot(valid_acc, color='b', label='valid accuracy')
ax1.legend()

ax2.plot(train_loss, color='r', label='train loss')
ax2.plot(valid_loss, color='b', label='valid loss')
ax2.legend()

plt.tight_layout()
plt.show()

# %%
### Image Augmentation (이미지 증식) ###

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# train_datagen = ImageDataGenerator(rescale=1/255)
datagen = ImageDataGenerator(rotation_range=20,
                             width_shift_range=0.1,
                             height_shift_range=0.1,
                             zoom_range=0.1,
                             horizontal_flip=True,
                             vertical_flip=True,
                             fill_mode='nearest')

img = image.load_img('./data/cat_dog_small/train/cats/cat.3.jpg',
                     target_size=(150,150))

x = image.img_to_array(img)
print(type(x), x.shape)

x = x.reshape((1,) + x.shape)
print(x.shape)

figure = plt.figure()
ax = []

for i in range(20):
    ax.append(figure.add_subplot(4,5,i+1))

idx = 0

for batch in datagen.flow(x, batch_size=1):
    ax[idx].imshow(image.array_to_img(batch[0]))
    idx += 1
    if idx == 20:
        break

plt.tight_layout()
plt.show()
# Out:
# <class 'numpy.ndarray'> (150, 150, 3)
# (1, 150, 150, 3)

# %%
### 증식을 이용해서 4000개의 이미지를 학습해요 ###

import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

train_dir = './data/cat_dog_small/train'    # cats folder, dogs folder
valid_dir = './data/cat_dog_small/validation'

# ImageDataGenerator를 생성해요!
train_datagen = ImageDataGenerator(rescale=1/255,
                                   rotation_range=30,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.2,
                                   horizontal_flip=True,                             
                                   fill_mode='nearest')

validation_datagen = ImageDataGenerator(rescale=1/255)

train_generator = train_datagen.flow_from_directory(
    train_dir,    # target directory
    classes=['cats', 'dogs'],
    target_size=(150,150),
    batch_size=20,
    class_mode='binary'
)

validation_generator = validation_datagen.flow_from_directory(
    valid_dir,    # target directory
    classes=['cats', 'dogs'],
    target_size=(150,150),
    batch_size=20,
    class_mode='binary'
)

import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop

model = Sequential()

model.add(Conv2D(filters=32,
                 kernel_size=(3,3),
                 activation='relu',
                 input_shape=(150,150,3)))

model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64,
                 kernel_size=(3,3),
                 activation='relu'))

model.add(Conv2D(filters=128,
                 kernel_size=(3,3),
                 activation='relu'))

model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=128,
                 kernel_size=(3,3),
                 activation='relu'))

model.add(MaxPooling2D(pool_size=(2,2)))

#### feature extraction ####

model.add(Flatten())

model.add(Dense(units=256,
                activation='relu'))

model.add(Dense(units=1,
                activation='sigmoid'))

print(model.summary())

model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_generator,    # 2000개 이미지 , 20개씩 뽑아내.. 100번
                   steps_per_epoch=100,
                   epochs=30,
                   validation_data=validation_generator,  # 1000개 이미지 , 20개
                   validation_steps=50)

model.save('./data/cats_dogs_small_cnn_model_augmentation.h5')

import matplotlib.pyplot as plt

train_acc = history.history['accuracy']
valid_acc = history.history['val_accuracy']

train_loss = history.history['loss']
valid_loss = history.history['val_loss']

figure = plt.figure()
ax1 = figure.add_subplot(1,2,1)
ax2 = figure.add_subplot(1,2,2)

ax1.plot(train_acc, color='r', label='train accuracy')
ax1.plot(valid_acc, color='b', label='valid accuracy')
ax1.legend()

ax2.plot(train_loss, color='r', label='train loss')
ax2.plot(valid_loss, color='b', label='valid loss')
ax2.legend()

plt.tight_layout()
plt.show()
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 70, 70, 128)       73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 35, 35, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 33, 33, 128)       147584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               8388864
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 8,629,953
# Trainable params: 8,629,953
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 100/100 [==============================] - 76s 748ms/step - loss: 0.6908 - accuracy: 0.5233 - val_loss: 0.6821 - val_accuracy: 0.5720
# Epoch 2/30
# 100/100 [==============================] - 75s 750ms/step - loss: 0.6743 - accuracy: 0.5637 - val_loss: 0.6420 - val_accuracy: 0.6100
# Epoch 3/30
# 100/100 [==============================] - 75s 749ms/step - loss: 0.6398 - accuracy: 0.6297 - val_loss: 0.6162 - val_accuracy: 0.6520
# Epoch 4/30
# 100/100 [==============================] - 74s 742ms/step - loss: 0.6010 - accuracy: 0.6698 - val_loss: 0.5912 - val_accuracy: 0.6700
# Epoch 5/30
# 100/100 [==============================] - 74s 744ms/step - loss: 0.6029 - accuracy: 0.6662 - val_loss: 0.5780 - val_accuracy: 0.6830
# Epoch 6/30
# 100/100 [==============================] - 74s 743ms/step - loss: 0.5577 - accuracy: 0.7083 - val_loss: 0.5792 - val_accuracy: 0.6890
# Epoch 7/30
# 100/100 [==============================] - 75s 749ms/step - loss: 0.5427 - accuracy: 0.7318 - val_loss: 0.5525 - val_accuracy: 0.7180
# Epoch 8/30
# 100/100 [==============================] - 74s 743ms/step - loss: 0.5513 - accuracy: 0.7175 - val_loss: 0.5823 - val_accuracy: 0.7100
# Epoch 9/30
# 100/100 [==============================] - 74s 740ms/step - loss: 0.5320 - accuracy: 0.7266 - val_loss: 0.5222 - val_accuracy: 0.7260
# Epoch 10/30
# 100/100 [==============================] - 75s 745ms/step - loss: 0.5103 - accuracy: 0.7457 - val_loss: 0.5810 - val_accuracy: 0.6940
# Epoch 11/30
# 100/100 [==============================] - 74s 744ms/step - loss: 0.5212 - accuracy: 0.7315 - val_loss: 0.5132 - val_accuracy: 0.7430
# Epoch 12/30
# 100/100 [==============================] - 75s 753ms/step - loss: 0.5056 - accuracy: 0.7534 - val_loss: 0.5611 - val_accuracy: 0.6910
# Epoch 13/30
# 100/100 [==============================] - 75s 744ms/step - loss: 0.5074 - accuracy: 0.7447 - val_loss: 0.4937 - val_accuracy: 0.7460
# Epoch 14/30
# 100/100 [==============================] - 75s 750ms/step - loss: 0.4855 - accuracy: 0.7596 - val_loss: 0.4959 - val_accuracy: 0.7490
# Epoch 15/30
# 100/100 [==============================] - 75s 754ms/step - loss: 0.5064 - accuracy: 0.7446 - val_loss: 0.5028 - val_accuracy: 0.7400
# Epoch 16/30
# 100/100 [==============================] - 75s 750ms/step - loss: 0.4823 - accuracy: 0.7667 - val_loss: 0.5121 - val_accuracy: 0.7490
# Epoch 17/30
# 100/100 [==============================] - 75s 751ms/step - loss: 0.4888 - accuracy: 0.7668 - val_loss: 0.5041 - val_accuracy: 0.7530
# Epoch 18/30
# 100/100 [==============================] - 75s 748ms/step - loss: 0.4614 - accuracy: 0.7846 - val_loss: 0.5032 - val_accuracy: 0.7460
# Epoch 19/30
# 100/100 [==============================] - 75s 749ms/step - loss: 0.4564 - accuracy: 0.7939 - val_loss: 0.4953 - val_accuracy: 0.7570
# Epoch 20/30
# 100/100 [==============================] - 75s 748ms/step - loss: 0.4515 - accuracy: 0.7825 - val_loss: 0.4966 - val_accuracy: 0.7540
# Epoch 21/30
# 100/100 [==============================] - 75s 750ms/step - loss: 0.4704 - accuracy: 0.7850 - val_loss: 0.5184 - val_accuracy: 0.7360
# Epoch 22/30
# 100/100 [==============================] - 75s 747ms/step - loss: 0.4521 - accuracy: 0.8006 - val_loss: 0.4756 - val_accuracy: 0.7490
# Epoch 23/30
# 100/100 [==============================] - 74s 742ms/step - loss: 0.4314 - accuracy: 0.7900 - val_loss: 0.4724 - val_accuracy: 0.7670
# Epoch 24/30
# 100/100 [==============================] - 74s 740ms/step - loss: 0.4658 - accuracy: 0.7779 - val_loss: 0.4544 - val_accuracy: 0.7790
# Epoch 25/30
# 100/100 [==============================] - 75s 747ms/step - loss: 0.4318 - accuracy: 0.7994 - val_loss: 0.5041 - val_accuracy: 0.7580
# Epoch 26/30
# 100/100 [==============================] - 74s 743ms/step - loss: 0.4337 - accuracy: 0.7899 - val_loss: 0.4916 - val_accuracy: 0.7670
# Epoch 27/30
# 100/100 [==============================] - 74s 742ms/step - loss: 0.4445 - accuracy: 0.7920 - val_loss: 0.4631 - val_accuracy: 0.7670
# Epoch 28/30
# 100/100 [==============================] - 75s 747ms/step - loss: 0.4307 - accuracy: 0.8087 - val_loss: 0.4480 - val_accuracy: 0.7860
# Epoch 29/30
# 100/100 [==============================] - 74s 743ms/step - loss: 0.4276 - accuracy: 0.7955 - val_loss: 0.4923 - val_accuracy: 0.7720
# Epoch 30/30
# 100/100 [==============================] - 75s 747ms/step - loss: 0.3937 - accuracy: 0.8147 - val_loss: 0.4923 - val_accuracy: 0.7730

# %%
### Transfer Learning ###

### keras는 전이학습을 위해서 VGG16을 제공해줘요!
from tensorflow.keras.applications import VGG16

model_base = VGG16(weights='imagenet',
                   include_top=False,
                   input_shape=(150,150,3))

print(model_base.summary())
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
## 우리가 가지고 있는 데이터(개와 고양이)를 VGG16에 통과시켜서
## activation map을 만들꺼예요!
## ndarray형태로 저장해야 해요!

import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

base_dir = './data/cat_dog_small'
train_dir = os.path.join(base_dir, 'train')  # ./data/cat_dog_small/train
valid_dir = os.path.join(base_dir, 'validation')
test_dir = os.path.join(base_dir, 'test')

datagen = ImageDataGenerator(rescale=1/255)

def extraction_feature(directory, sample_count):
    features = np.zeros(shape=(sample_count,4,4,512))
    labels = np.zeros(shape=(sample_count,))
    
    generator = datagen.flow_from_directory(
        directory,
        classes=['cats', 'dogs'],
        target_size=(150,150),
        batch_size=20,
        class_mode='binary'
    )
    
    i = 0
    
    for x_data_batch, t_data_batch in generator:
        feature_batch = model_base.predict(x_data_batch)  # 20개 이미지 특성추출.
        features[i*20:(i+1)*20] = feature_batch
        labels[i*20:(i+1)*20] = t_data_batch
        
        i = i + 1
        
        if i*20 >= sample_count:
            break
            
    return features, labels
    

train_features, train_labels = extraction_feature(train_dir, 2000)
valid_features, valid_labels = extraction_feature(valid_dir, 1000)
test_features, test_labels = extraction_feature(test_dir, 1000)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
## 이 activation map을 이용해서 DNN 학습을 하면 될 거 같아요!

train_x_data = np.reshape(train_features,(2000,4*4*512))  # 2차원
train_t_data = train_labels

valid_x_data = np.reshape(valid_features,(1000,4*4*512))  # 2차원
valid_t_data = valid_labels

test_x_data = np.reshape(test_features,(1000,4*4*512))  # 2차원
test_t_data = test_labels

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

model = Sequential()

model.add(Flatten(input_shape=(4*4*512,)))

model.add(Dense(units=256,
                activation='relu'))
model.add(Dropout(rate=0.5))

model.add(Dense(units=1,
                activation='sigmoid'))

model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_x_data,
                    train_t_data,
                    epochs=30,
                    batch_size=20,
                    validation_data=(valid_x_data, valid_t_data))
# Out:
# Epoch 1/30
# 100/100 [==============================] - 2s 15ms/step - loss: 0.5602 - accuracy: 0.6916 - val_loss: 0.3188 - val_accuracy: 0.8790
# Epoch 2/30
# 100/100 [==============================] - 1s 13ms/step - loss: 0.3232 - accuracy: 0.8637 - val_loss: 0.2567 - val_accuracy: 0.9010
# Epoch 3/30
# 100/100 [==============================] - 1s 13ms/step - loss: 0.2273 - accuracy: 0.9124 - val_loss: 0.2458 - val_accuracy: 0.9030
# Epoch 4/30
# 100/100 [==============================] - 2s 17ms/step - loss: 0.1930 - accuracy: 0.9288 - val_loss: 0.2530 - val_accuracy: 0.8960
# Epoch 5/30
# 100/100 [==============================] - 1s 15ms/step - loss: 0.1549 - accuracy: 0.9398 - val_loss: 0.2309 - val_accuracy: 0.9150
# Epoch 6/30
# 100/100 [==============================] - 1s 14ms/step - loss: 0.1354 - accuracy: 0.9508 - val_loss: 0.2389 - val_accuracy: 0.9080
# Epoch 7/30
# 100/100 [==============================] - 1s 14ms/step - loss: 0.1261 - accuracy: 0.9547 - val_loss: 0.2310 - val_accuracy: 0.9070
# Epoch 8/30
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0968 - accuracy: 0.9768 - val_loss: 0.2299 - val_accuracy: 0.9140
# Epoch 9/30
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0883 - accuracy: 0.9747 - val_loss: 0.2361 - val_accuracy: 0.9090
# Epoch 10/30
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0698 - accuracy: 0.9854 - val_loss: 0.2360 - val_accuracy: 0.9100
# Epoch 11/30
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0639 - accuracy: 0.9836 - val_loss: 0.2485 - val_accuracy: 0.9040
# Epoch 12/30
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0537 - accuracy: 0.9906 - val_loss: 0.2489 - val_accuracy: 0.9110
# Epoch 13/30
# 100/100 [==============================] - 2s 15ms/step - loss: 0.0479 - accuracy: 0.9914 - val_loss: 0.2458 - val_accuracy: 0.9080
# Epoch 14/30
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0456 - accuracy: 0.9893 - val_loss: 0.2504 - val_accuracy: 0.9090
# Epoch 15/30
# 100/100 [==============================] - 1s 15ms/step - loss: 0.0354 - accuracy: 0.9935 - val_loss: 0.2615 - val_accuracy: 0.9040
# Epoch 16/30
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0326 - accuracy: 0.9956 - val_loss: 0.2582 - val_accuracy: 0.9050
# Epoch 17/30
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0274 - accuracy: 0.9984 - val_loss: 0.2587 - val_accuracy: 0.9060
# Epoch 18/30
# 100/100 [==============================] - 1s 15ms/step - loss: 0.0259 - accuracy: 0.9995 - val_loss: 0.2894 - val_accuracy: 0.8970
# Epoch 19/30
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0238 - accuracy: 0.9975 - val_loss: 0.2679 - val_accuracy: 0.9030
# Epoch 20/30
# 100/100 [==============================] - 1s 14ms/step - loss: 0.0208 - accuracy: 0.9967 - val_loss: 0.2815 - val_accuracy: 0.9050
# Epoch 21/30
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0211 - accuracy: 0.9985 - val_loss: 0.2673 - val_accuracy: 0.9090
# Epoch 22/30
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0149 - accuracy: 0.9996 - val_loss: 0.2773 - val_accuracy: 0.9080
# Epoch 23/30
# 100/100 [==============================] - 1s 14ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.2923 - val_accuracy: 0.9080
# Epoch 24/30
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0138 - accuracy: 0.9999 - val_loss: 0.2884 - val_accuracy: 0.9030
# Epoch 25/30
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.2958 - val_accuracy: 0.9050
# Epoch 26/30
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.3053 - val_accuracy: 0.9070
# Epoch 27/30
# 100/100 [==============================] - 1s 15ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.3074 - val_accuracy: 0.8980
# Epoch 28/30
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.3040 - val_accuracy: 0.9070
# Epoch 29/30
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.3053 - val_accuracy: 0.9070
# Epoch 30/30
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.3236 - val_accuracy: 0.9100
